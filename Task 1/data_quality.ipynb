# %%
# importing necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %% [markdown]
# ### Transaction dataset

# %%
# read transaction sheet
df_sheet_map = pd.read_excel(r"C:\Users\RUDRO\OneDrive - The University of Kansas\RUDRO\Study Documents\KPMG_Analytics/KPMG_VI_New_raw_data_update_final.xlsx", sheet_name=None)

# %%
df_sheet_map['Transactions'].head(10)
# Out:
#    transaction_id  product_id  customer_id     transaction_date  online_order  \
# 0  transaction_id  product_id  customer_id     transaction_date  online_order
# 1               1           2         2950  2017-02-25 00:00:00         False
# 2               2           3         3120  2017-05-21 00:00:00          True
# 3               3          37          402  2017-10-16 00:00:00         False
# 4               4          88         3135  2017-08-31 00:00:00         False
# 5               5          78          787  2017-10-01 00:00:00          True
# 6               6          25         2339  2017-03-08 00:00:00          True
# 7               7          22         1542  2017-04-21 00:00:00          True
# 8               8          15         2459  2017-07-15 00:00:00         False
# 9               9          67         1305  2017-08-10 00:00:00         False
#
#    order_status           brand  product_line  product_class  product_size  \
# ...

# %%
df_sheet_map['Transactions'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20001 entries, 0 to 20000
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20001 non-null  object
#  1   product_id               20001 non-null  object
#  2   customer_id              20001 non-null  object
#  3   transaction_date         20001 non-null  object
#  4   online_order             19641 non-null  object
#  5   order_status             20001 non-null  object
#  6   brand                    19804 non-null  object
#  7   product_line             19804 non-null  object
#  8   product_class            19804 non-null  object
#  9   product_size             19804 non-null  object
#  10  list_price               20001 non-null  object
#  11  standard_cost            19804 non-null  object
#  12  product_first_sold_date  19804 non-null  object
# dtypes: object(13)
# memory usage: 2.0+ MB

# %%
df_sheet_map['Transactions'].describe()
# Out:
#         transaction_id  product_id  customer_id     transaction_date  \
# count            20001       20001        20001                20001
# unique           20001         102         3495                  365
# top     transaction_id           0         1068  2017-02-14 00:00:00
# freq                 1        1378           14                   82
#
#        online_order order_status  brand product_line product_class  \
# count         19641        20001  19804        19804         19804
# unique            3            3      7            5             4
# top            True     Approved  Solex     Standard        medium
# freq           9829        19821   4253        14176         13826
#
#        product_size  list_price  standard_cost  product_first_sold_date
# count         19804    20001.00       19804.00                    19804
# unique            4      297.00         104.00                      101
# ...

# %%
# using isnull() function to check for null values
df_sheet_map['Transactions'].isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
# we have missing values in 
# online_order               360
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# standard_cost              197
# product_first_sold_date    197

# %%
# Let's fill them using the previous or next value
df_sheet_map['Transactions'].fillna("bfill").isnull().sum()
# Out:
# transaction_id             0
# product_id                 0
# customer_id                0
# transaction_date           0
# online_order               0
# order_status               0
# brand                      0
# product_line               0
# product_class              0
# product_size               0
# list_price                 0
# standard_cost              0
# product_first_sold_date    0
# dtype: int64

# %%
# let's check for duplicates in our transactions dataframes
df_sheet_map['Transactions'].duplicated().sum()
df_sheet_map['Transactions'].to_csv (r'C:\Users\RUDRO\OneDrive - The University of Kansas\RUDRO\Study Documents\KPMG_Analytics\Task 1\transaction.csv', index = None, header=True)

# %%
# we are done with the transaction data
# let's move on to the customer demographic dataset

# %% [markdown]
# ### Customer address dataset

# %%
# read data
df_sheet_map['CustomerAddress'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         4000 non-null   object
#  1   address             4000 non-null   object
#  2   postcode            4000 non-null   object
#  3   state               4000 non-null   object
#  4   country             4000 non-null   object
#  5   property_valuation  4000 non-null   object
# dtypes: object(6)
# memory usage: 187.6+ KB

# %%
df_sheet_map['CustomerAddress'].describe()
# Out:
#         customer_id           address  postcode state    country  \
# count          4000              4000      4000  4000       4000
# unique         4000              3997       874     6          2
# top     customer_id  3 Talisman Place      2170   NSW  Australia
# freq              1                 2        31  2054       3999
#
#         property_valuation
# count                 4000
# unique                  13
# top                      9
# freq                   647

# %%
# using isnull() function to check for null values
df_sheet_map['CustomerAddress'].isnull().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
# let's check for duplicates in our transactions dataframes
df_sheet_map['CustomerAddress'].duplicated().sum()
df_sheet_map['CustomerAddress'].to_csv (r'C:\Users\RUDRO\OneDrive - The University of Kansas\RUDRO\Study Documents\KPMG_Analytics\Task 1\customer_address.csv', index = None, header=True)

# %%
# Overall, the customer address dataset seems fairly nice and clean
# We will now deal with the customer demographic which is a bit larger

# %% [markdown]
# ### Customer demographic dataset

# %%
df_sheet_map['CustomerDemographic'].head(20)
# Out:
#     customer_id      first_name  last_name  gender  \
# 0   customer_id      first_name  last_name  gender
# 1             1         Laraine  Medendorp       F
# 2             2             Eli    Bockman    Male
# 3             3           Arlin     Dearle    Male
# 4             4          Talbot        NaN    Male
# 5             5  Sheila-kathryn     Calton  Female
# 6             6            Curr  Duckhouse    Male
# 7             7            Fina     Merali  Female
# 8             8             Rod      Inder    Male
# 9             9            Mala       Lind  Female
# 10           10        Fiorenze    Birdall  Female
# 11           11           Uriah     Bisatt    Male
# 12           12         Sawyere   Flattman    Male
# 13           13        Gabriele   Norcross    Male
# 14           14        Rayshell   Kitteman  Female
# 15           15          Erroll     Radage    Male
# 16           16          Harlin       Parr    Male
# ...

# %%
df_sheet_map['CustomerDemographic'].describe()
# Out:
#         customer_id first_name last_name  gender  \
# count          4001       4001      3876    4001
# unique         4001       3140      3726       7
# top     customer_id       Tobe  Ramsdell  Female
# freq              1          5         3    2037
#
#         past_3_years_bike_related_purchases                  DOB  \
# count                                  4001                 3914
# unique                                  101                 3449
# top                                      16  1978-01-30 00:00:00
# freq                                     56                    7
#
#                                    job_title job_industry_category  \
# count                                   3495                  3345
# unique                                   196                    10
# top     Business Systems Development Analyst         Manufacturing
# freq                                      45                   799
#
# ...

# %%
df_sheet_map['CustomerDemographic'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4001 entries, 0 to 4000
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4001 non-null   object
#  1   first_name                           4001 non-null   object
#  2   last_name                            3876 non-null   object
#  3   gender                               4001 non-null   object
#  4   past_3_years_bike_related_purchases  4001 non-null   object
#  5   DOB                                  3914 non-null   object
#  6   job_title                            3495 non-null   object
#  7   job_industry_category                3345 non-null   object
#  8   wealth_segment                       4001 non-null   object
#  9   deceased_indicator                   4001 non-null   object
#  10  default                              3699 non-null   object
# ...

# %%
# using isnull() function to check for null values
df_sheet_map['CustomerDemographic'].isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
# let's check for duplicates in our transactions dataframes
df_sheet_map['CustomerDemographic'].duplicated().sum()
# Out:
# 0

# %%
# it's good that we don't have duplicates

# %%
# The default column seems to be a big miss with symbols and characters
# let's clean that column now
# actually, we can just drop that column

# %%
# let's check for duplicates in our transactions dataframes
df_sheet_map['CustomerDemographic'] = df_sheet_map['CustomerDemographic'].drop('default', axis = 1)

# %%
df_sheet_map['CustomerDemographic'].head(10)
# Out:
#    customer_id      first_name  last_name  gender  \
# 0  customer_id      first_name  last_name  gender
# 1            1         Laraine  Medendorp       F
# 2            2             Eli    Bockman    Male
# 3            3           Arlin     Dearle    Male
# 4            4          Talbot        NaN    Male
# 5            5  Sheila-kathryn     Calton  Female
# 6            6            Curr  Duckhouse    Male
# 7            7            Fina     Merali  Female
# 8            8             Rod      Inder    Male
# 9            9            Mala       Lind  Female
#
#    past_3_years_bike_related_purchases                  DOB  \
# 0  past_3_years_bike_related_purchases                  DOB
# 1                                   93  1953-10-12 00:00:00
# 2                                   81  1980-12-16 00:00:00
# 3                                   61  1954-01-20 00:00:00
# 4                                   33  1961-10-03 00:00:00
# ...

# %%
# the last name column has missing values but we can't fill them since they are people's names

# %%
df_sheet_map['CustomerDemographic']['job_title'].value_counts()
# Out:
# Business Systems Development Analyst    45
# Social Worker                           44
# Tax Accountant                          44
# Internal Auditor                        42
# Recruiting Manager                      41
#                                         ..
# Research Assistant III                   3
# Health Coach III                         3
# Health Coach I                           3
# Developer I                              1
# job_title                                1
# Name: job_title, Length: 196, dtype: int64

# %%
df_sheet_map['CustomerDemographic']['job_title'].isnull().sum()
# Out:
# 506

# %%
# we have some inconsistency for the gender column

# %%
#Re-naming the categories
df_sheet_map['CustomerDemographic']['gender'] = df_sheet_map['CustomerDemographic']['gender'].replace('F','Female').replace('M','Male').replace('Femal','Female').replace('U','Unspecified')

# %%
df_sheet_map['CustomerDemographic']
# Out:
#       customer_id  first_name  last_name       gender  \
# 0     customer_id  first_name  last_name       gender
# 1               1     Laraine  Medendorp       Female
# 2               2         Eli    Bockman         Male
# 3               3       Arlin     Dearle         Male
# 4               4      Talbot        NaN         Male
# ...           ...         ...        ...          ...
# 3996         3996     Rosalia   Halgarth       Female
# 3997         3997      Blanch     Nisuis       Female
# 3998         3998      Sarene    Woolley  Unspecified
# 3999         3999   Patrizius        NaN         Male
# 4000         4000       Kippy    Oldland         Male
#
#       past_3_years_bike_related_purchases                  DOB  \
# 0     past_3_years_bike_related_purchases                  DOB
# 1                                      93  1953-10-12 00:00:00
# 2                                      81  1980-12-16 00:00:00
# ...

# %%
# let's fill the tenure column
df_sheet_map['CustomerDemographic']['tenure'].fillna("bfill")
# Out:
# 0       tenure
# 1           11
# 2           16
# 3           15
# 4            7
#          ...
# 3996        19
# 3997         1
# 3998     bfill
# 3999        10
# 4000        11
# Name: tenure, Length: 4001, dtype: object

# %%
df_sheet_map['CustomerDemographic']['tenure'].value_counts()
# Out:
# 7         235
# 5         228
# 11        221
# 10        218
# 16        215
# 8         211
# 18        208
# 12        202
# 9         200
# 14        200
# 6         192
# 13        191
# 4         191
# 17        182
# 15        179
# 1         166
# 3         160
# 19        159
# 2         150
# 20         96
# 22         55
# 21         54
# tenure      1
# Name: tenure, dtype: int64

# %%
df_sheet_map['CustomerDemographic'].to_csv (r'C:\Users\RUDRO\OneDrive - The University of Kansas\RUDRO\Study Documents\KPMG_Analytics\Task 1\demographic.csv', index = None, header=True)

# %% [markdown]
# Dear client,
#
# This is Rudro. I have been working on the task of looking into the transaction and customer dataset. After careful analysis, I was able to find out the data had misssing values and had some garbage values which would pose problem in the long run for running predictions. There weren't any duplicates but some of the data had been formatted to fit the overall dataset.
